# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

df_assistance_program = pd.read_csv("../Data/Cleaned Data/df_assistance_program.csv")
df_assistance_program.head()
